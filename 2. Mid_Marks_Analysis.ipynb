# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_excel("MIDMARKS.xlsx")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  691 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  718 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     718 non-null    int64
#  1   SECTION  718 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 45.0+ KB

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       716 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 50.3+ KB

# %%
df = df.dropna(how='all')

# %%
print(df.shape)
# Out:
# (716, 8)

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df.fillna(0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
print(df['S.NO'].dtypes)
# Out:
# int64

# %%
columns_to_drop = [col for col in  df.columns]

# %%
columns_to_drop
# Out:
# ['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df.plot()
plt.show()

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
columns_to_convert = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0)

# %%
df.SECTION.count
# Out:
# <bound method Series.count of 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 713     ZETA
# 714     ZETA
# 715     ZETA
# 716     ZETA
# 717     ZETA
# Name: SECTION, Length: 716, dtype: object>

# %%
df.SECTION.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 713     ZETA
# 714     ZETA
# 715     ZETA
# 716     ZETA
# 717     ZETA
# Name: SECTION, Length: 716, dtype: object>

# %%
df.DV.value_counts()
# Out:
# DV
# 20.0    103
# 17.0     79
# 16.0     74
# 18.0     69
# 15.0     63
# 19.0     60
# 11.0     43
# 12.0     41
# 14.0     41
# 13.0     30
# 10.0     26
# 9.0      20
# 6.0      12
# 0.0      11
# 5.0      11
# 8.0      11
# 7.0       8
# 2.0       6
# 4.0       4
# 1.0       3
# 3.0       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
sns.histplot(df['DV'], bins=12,color='yellow')
plt.title('Histogram  of Marks in DV', fontsize=16)
plt.xlabel('Marks in DV', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'DV'. Peaks in the histogram indicate the marks ranges most  students achieved.

# %%
plt.figure(figsize=(9,7))
sns.histplot(df['M-II'], bins=8,color='pink')
plt.title('Histogram  of Marks in M-II', fontsize=16)
plt.xlabel('Marks in M-II', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'M-11'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(9,9))
sns.histplot(df['PP'], bins=11,color='gray')
plt.title('Histogram of Marks in PP', fontsize=16)
plt.xlabel('Marks in PP', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'PP'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(8, 8))
sns.histplot(df['BEEE'], bins=14,color='blue')
plt.title('Histogram of Marks in BEEE', fontsize=16)
plt.xlabel('Marks in BEEE', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'BEEE'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['FL'], bins=10,color='black')
plt.title('Histogram of Marks in FL', fontsize=16)
plt.xlabel('Marks in FL', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'FL'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(7,7))
sns.histplot(df['FIMS'], bins=10,color='purple')
plt.title('Histogram of Marks in FIMS', fontsize=16)
plt.xlabel('Marks in FIMS', fontsize=8)
plt.ylabel('Frequency', fontsize=8)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'FIMS'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
col = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']

# %%
df[col] = df[col].apply(pd.to_numeric, errors='coerce')

# %%
df[col] = df[col].fillna(0)

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
df['TOTAL'] = df[col].sum(axis=1)

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0
#
# [716 rows x 9 columns]

# %%
df.TOTAL.tail(10)
# Out:
# 708     80.0
# 709    101.0
# 710     57.0
# 711     91.0
# 712     84.0
# 713     89.0
# 714     58.0
# 715     86.0
# 716     53.0
# 717    105.0
# Name: TOTAL, dtype: float64

# %%
df.head(10)
# Out:
#    S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL
# 0     1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1     2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2     3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3     4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4     5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# 5     6   ALPHA  17.0  16.0  18.0  10.0  15.0   9.0   85.0
# 6     7   ALPHA  15.0  10.0  20.0  20.0  15.0  14.0   94.0
# 7     8   ALPHA  17.0  17.0  19.0  20.0  19.0  13.0  105.0
# 8     9   ALPHA  10.0  18.0   0.0  20.0  19.0  15.0   82.0
# 9    10   ALPHA  18.0  19.0  20.0  20.0  20.0  15.0  112.0

# %%
plt.figure(figsize=[6,9])
plt.hist(df['TOTAL'], color='black', bins=10, edgecolor='black')
plt.title("Histogram of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# Histogram of total marks

# %%
col = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
sub = df[col].mean()

# %%
sub
# Out:
# DV      14.787709
# M-II     9.949721
# PP      12.769553
# BEEE    13.287709
# FL      15.544693
# FIMS    14.047486
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
sub.plot(kind='bar', color='green')
plt.title('Average Marks per Subject', fontsize=10)
plt.xlabel('Subjects', fontsize=10)
plt.ylabel('Average Marks', fontsize=10)
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Average marks each subject

# %%
average_total_by_section = df.groupby('SECTION')['TOTAL'].mean()
plt.figure(figsize=[8,8])
average_total_by_section.plot(kind='bar', color='red', edgecolor='black')
plt.title(" Section Average Total Marks")
plt.xlabel("Section")
plt.ylabel("Average Total Marks")
plt.show()

# %% [markdown]
# Average of total marks in each section

# %%
avg = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean().idxmax()
plt.figure(figsize=(9,9))
sns.histplot(df[avg], bins=10, color='blue')
plt.title(f'Histogram of Marks in {avg}', fontsize=20)
plt.xlabel(f'Marks in {avg}', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.show()

# %% [markdown]
# Histogram of marks in FL subject

# %%
df['Total'] = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].sum(axis=1)
subjectmax = 100
subjectsnum = len(['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'])
totalmarks = subjectmax * subjectsnum
df['Percentage'] = (df['Total'] / totalmarks) * 100

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   72.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   84.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  102.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   94.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   89.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   58.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   86.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   53.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  105.0
#
#      Percentage
# 0     12.000000
# 1     14.000000
# 2     17.000000
# 3     15.666667
# 4     18.500000
# ..          ...
# 713   14.833333
# 714    9.666667
# 715   14.333333
# 716    8.833333
# 717   17.500000
#
# [716 rows x 11 columns]

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Percentage'], bins=10, color='violet')
plt.title('Histogram of Percentages', fontsize=15)
plt.xlabel('Percentage', fontsize=20)
plt.ylabel('Frequency', fontsize=20)
plt.show()

# %% [markdown]
# Histogram of Percentages

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Total', y='Percentage', color='red', s=10)
plt.title('Relationship Between Total Marks and Percentage', fontsize=16)
plt.xlabel('Total Marks')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# Relationship Between Total Marks and Percentage.

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='DV', y='M-II', color='teal')
plt.title('Scatter Plot of Marks: DV vs M-II', fontsize=16)
plt.xlabel('Marks in DV', fontsize=12)
plt.ylabel('Marks in M-II', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Scatter Plot of Marks: DV vs M-II.Plot shows the correlation between marks in these two subjects.

# %%
plt.figure(figsize=[8, 6])
plt.scatter(df['TOTAL'], df['BEEE'], color='black', edgecolor='black')
plt.title("Scatter Plot: Total Marks vs BEEE Marks")
plt.xlabel("Total Marks")
plt.ylabel("BEEE Marks")
plt.show()

# %% [markdown]
# Plot shows the correlation between marks in these two subjects relationship Between Marks in total Marks vs BEEE Marks.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='PP', y='BEEE', color='skyblue', s=100)
plt.title('Relationship Between Marks in PP and BEEE', fontsize=16)
plt.xlabel('Marks in PP', fontsize=12)
plt.ylabel('Marks in BEEE', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Plot shows the correlation between marks in these two subjects relationship Between Marks in PP and BEEE.

# %%
df.boxplot(by='DV', column =['TOTAL'], grid = False,color='brown',figsize=[5,6])
plt.title("Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of the marks of DV in this range got marks between 01  and 20, the maximum mark is 20 and minimum mark i and 0.

# %%
df.boxplot(by='M-II', column =['TOTAL'], grid = False,color='blue',figsize=[5,6])
plt.title("Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of the marks of M-II in this range got marks between 01  and 20, the maximum mark is 20 and minimum mark i and 0.

# %%
df.boxplot(by='PP', column =['Total'], grid = False,color='yellow',figsize=[5,6])
plt.title("Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# This pie chart represents according to the Subject Average Scores in subject.

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("Subject-wise Average Scores")
plt.ylabel('subject')
plt.show()

# %% [markdown]
# This pie chart represents according to the Subject Average Scores in section wise.

# %%
df.SECTION.count
# Out:
# <bound method Series.count of 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 713     ZETA
# 714     ZETA
# 715     ZETA
# 716     ZETA
# 717     ZETA
# Name: SECTION, Length: 716, dtype: object>

# %%
df= df.loc[df.groupby('SECTION')['TOTAL'].idxmax()]
print(df)
# Out:
#      S.NO  SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 23     24    ALPHA  20.0  20.0  20.0  20.0  20.0  18.0  118.0  118.0
# 115   116     BETA  20.0  20.0  20.0  20.0  20.0  17.0  117.0  117.0
# 251   252    DELTA  20.0  20.0  20.0  19.0  20.0  20.0  119.0  119.0
# 346   347  EPSILON  19.0  20.0  18.0  20.0  20.0  17.0  114.0  114.0
# 440   441    GAMMA  20.0  20.0  20.0  20.0  20.0  18.0  118.0  118.0
# 505   506    OMEGA  20.0  20.0  20.0  20.0  20.0  20.0  120.0  120.0
# 574   575    SIGMA  20.0  20.0  20.0  20.0  20.0  20.0  120.0  120.0
# 653   654     ZETA  20.0  20.0  16.0  20.0  20.0  18.0  114.0  114.0
#
#      Percentage
# 23    19.666667
# 115   19.500000
# 251   19.833333
# 346   19.000000
# 440   19.666667
# 505   20.000000
# 574   20.000000
# 653   19.000000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df= df[df['SECTION'] == 'ALPHA'].sort_values(by='Total', ascending=False).iloc[0]
print(df)
# Out:
# S.NO                 24
# SECTION           ALPHA
# DV                 20.0
# M-II               20.0
# PP                 20.0
# BEEE               20.0
# FL                 20.0
# FIMS               18.0
# TOTAL             118.0
# Total             118.0
# Percentage    19.666667
# Name: 23, dtype: object

# %%
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel("MIDMARKS.xlsx")

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
columns_to_sum = ['S.NO','DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[columns_to_sum] = df[columns_to_sum].apply(pd.to_numeric, errors='coerce')

# %%
df[columns_to_sum] = df[columns_to_sum].fillna(0)

# %%
df['Total'] = df[columns_to_sum].sum(axis=1)

# %%
sns.lineplot(x='DV', y='Total', data=df)
plt.title('Line Plot of DV vs Total')
plt.show()

# %% [markdown]
# Line plot of DV and Total

# %%
sns.lineplot(x='SECTION', y='Total', data=df)
plt.title('Line Plot of SECTION vs Total')
plt.show()

# %%
sns.relplot(data=df, x="Total", y="SECTION", hue="FIMS")

# %%
sns.relplot(data=df, x="SECTION", y="DV", hue="FIMS", kind="line")

# %%
sns.relplot(data=df, x="DV", y="SECTION", hue="Total", kind="line")

# %%
sns.lineplot(x="SECTION", y="Total", data=df) 
sns.set_style("dark")
plt.show()

# %%
sns.lineplot(x="DV", y="Total", data=df) 
sns.despine()
plt.show()

# %%
plt.figure(figsize = (2, 4))
sns.lineplot(x="DV", y="SECTION", data=df)
# Out:
# <Axes: xlabel='DV', ylabel='SECTION'>

# %%
sns.set_context("paper",font_scale=1.02)
sns.lineplot(x="SECTION", y="DV", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='DV'>

# %%
sns.lineplot(x="SECTION", y="FIMS", data=df) 
with sns.axes_style('darkgrid'):
          sns.lineplot(x="SECTION", y="FIMS", data=df)

# %%
sns.set_palette('Accent')
sns.lineplot(x="DV", y="SECTION", data=df)
# Out:
# <Axes: xlabel='DV', ylabel='SECTION'>

# %%
def graph():
    sns.lineplot(x="PP", y="Total", data=df)
plt.subplot(121)
graph()
plt.subplot(122)
graph()

# %%
df['BC'] = (df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
# [718 rows x 10 columns]

# %%
bc = []
for i in range(len(df)):
    count = 0
    if df.iloc[i]['DV'] < 10:
        count += 1
    if df.iloc[i]['M-II'] < 10:
        count += 1
    if df.iloc[i]['PP'] < 10:
        count += 1
    if df.iloc[i]['BEEE'] < 10:
        count += 1
    if df.iloc[i]['FL'] < 10:
        count += 1
    if df.iloc[i]['FIMS'] < 10:
        count += 1
    bc.append(count)

df['BC'] = bc
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
# [718 rows x 10 columns]

# %%
df.BC.value_counts()
# Out:
# BC
# 0    273
# 1    172
# 2    121
# 3     69
# 4     43
# 5     23
# 6     17
# Name: count, dtype: int64

# %%
print(df[['PP','BC']])
# Out:
#        PP  BC
# 0    17.0   2
# 1    16.0   1
# 2    18.0   0
# 3    19.0   1
# 4    19.0   0
# ..    ...  ..
# 713   8.0   2
# 714   7.0   3
# 715  14.0   1
# 716   6.0   3
# 717  17.0   0
#
# [718 rows x 2 columns]

# %%
sns.lineplot(x='BC', y='Total', data=df)
plt.title('Line Plot of BC vs Total')
plt.show()

# %%
sns.lineplot(x='SECTION', y='BC', data=df)
plt.title('Line Plot of DV vs BC')
plt.show()

# %%
sns.lineplot(x='SECTION', y='BC', data=df)
plt.title('Line Plot of SECTION vs BC')
plt.show()

# %%
sns.relplot(data=df, x="BC", y="SECTION", hue="FIMS")

# %%
sns.relplot(data=df, x="BC", y="SECTION", hue="Total", kind="line")

# %%
sns.lineplot(x="SECTION", y="BC", data=df) 
sns.set_style("dark")
plt.show()

# %%
plt.figure(figsize = (5,5))
sns.lineplot(x="SECTION", y="BC", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='BC'>

# %%
sns.set_context("paper",font_scale=1.02)
sns.lineplot(x="SECTION", y="BC", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='BC'>

# %%
sns.lineplot(x="SECTION", y="FIMS", data=df) 
with sns.axes_style('darkgrid'):
          sns.lineplot(x="FIMS", y="BC", data=df)

# %%
sns.set_palette('Accent')
sns.lineplot(x="SECTION", y="BC", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='BC'>

# %%
def graph():
    sns.lineplot(x="PP", y="BC", data=df)
plt.subplot(121)
graph()
plt.subplot(122)
graph()

# %%
def graph():
    sns.lineplot(x="SECTION", y="BC", data=df)
plt.subplot(121)
graph()
plt.subplot(122)
graph()

# %%
plt.figure(figsize=[6,9])
plt.hist(df['BC'], color='black', bins=10, edgecolor='black')
plt.title("Histogram of BC Marks")
plt.xlabel("BC Marks")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='DV', y='BC', color='teal')
plt.title('Scatter Plot of Marks: DV vs M-II', fontsize=16)
plt.xlabel('Marks in DV', fontsize=12)
plt.ylabel('Marks in BC', fontsize=12)
plt.grid(True)
plt.show()

# %%
df.boxplot(by='SECTION', column =['BC'], grid = False,color='blue',figsize=[5,6])
plt.title("BC Marks")
plt.ylabel("SECTION")
plt.show()

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("BC")
plt.ylabel('SECTION')
plt.show()

# %% [markdown]
# CASE STUDY - 2

# %% [markdown]
# HARSHITHA HRIDYA

# %% [markdown]
# 2211CS010102

# %% [markdown]
# GROUP - 4

# %%
def classify_score(score):
    if 18 <= score <= 20:
        return "Very Good"
    elif 13 <= score <= 17:
        return "Good"
    elif 13 <= score <= 14:  
        return "Average"
    else:
        return "Poor"


ratings = []
for i in range(len(df)):
    row_ratings = {
        'DV': classify_score(df.iloc[i]['DV']),
        'M-II': classify_score(df.iloc[i]['M-II']),
        'PP': classify_score(df.iloc[i]['PP']),
        'BEEE': classify_score(df.iloc[i]['BEEE']),
        'FL': classify_score(df.iloc[i]['FL']),
        'FIMS': classify_score(df.iloc[i]['FIMS']),
    }
    ratings.append(row_ratings)


ratings_df = pd.DataFrame(ratings)
df = pd.concat([df, ratings_df.add_suffix('_Rating')], axis=1)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  DV_Rating  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2       Poor
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1  Very Good
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0  Very Good
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1       Good
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0  Very Good
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..        ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2  Very Good
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3       Poor
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1       Good
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3       Poor
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0  Very Good
#
#     M-II_Rating  PP_Rating BEEE_Rating  FL_Rating FIMS_Rating
# 0          Poor       Good        Poor  Very Good        Good
# 1          Poor       Good        Good  Very Good        Poor
# 2          Good  Very Good   Very Good  Very Good        Good
# 3          Poor  Very Good        Good  Very Good        Good
# 4          Good  Very Good   Very Good  Very Good   Very Good
# ..          ...        ...         ...        ...         ...
# 713        Poor       Poor   Very Good       Good   Very Good
# 714        Poor       Poor        Poor  Very Good        Poor
# 715        Poor       Good        Good       Good   Very Good
# 716        Poor       Poor        Poor       Good        Poor
# 717        Good       Good        Good  Very Good   Very Good
#
# [718 rows x 16 columns]

# %%
df['Total_Score'] = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].sum(axis=1)
def classify_overall(score):
    if 18 <= score <= 20:
        return "Very Good"
    elif 13 <= score <= 17:
        return "Good"
    elif 10 <= score <= 12:
        return "Average"
    else:
        return "Poor"
df['Overall_Rating'] = df['Total_Score'].apply(classify_overall)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  DV_Rating  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2       Poor
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1  Very Good
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0  Very Good
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1       Good
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0  Very Good
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..        ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2  Very Good
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3       Poor
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1       Good
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3       Poor
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0  Very Good
#
#     M-II_Rating  PP_Rating BEEE_Rating  FL_Rating FIMS_Rating  Total_Score  \
# 0          Poor       Good        Poor  Very Good        Good         72.0
# 1          Poor       Good        Good  Very Good        Poor         84.0
# 2          Good  Very Good   Very Good  Very Good        Good        102.0
# 3          Poor  Very Good        Good  Very Good        Good         94.0
# 4          Good  Very Good   Very Good  Very Good   Very Good        111.0
# ..          ...        ...         ...        ...         ...          ...
# 713        Poor       Poor   Very Good       Good   Very Good         89.0
# 714        Poor       Poor        Poor  Very Good        Poor         58.0
# 715        Poor       Good        Good       Good   Very Good         86.0
# 716        Poor       Poor        Poor       Good        Poor         53.0
# 717        Good       Good        Good  Very Good   Very Good        105.0
#
#     Overall_Rating
# 0             Poor
# 1             Poor
# 2             Poor
# 3             Poor
# 4             Poor
# ..             ...
# 713           Poor
# 714           Poor
# 715           Poor
# 716           Poor
# 717           Poor
#
# [718 rows x 18 columns]

# %%
print(df[['PP','Total_Score']])
# Out:
#        PP  Total_Score
# 0    17.0         72.0
# 1    16.0         84.0
# 2    18.0        102.0
# 3    19.0         94.0
# 4    19.0        111.0
# ..    ...          ...
# 713   8.0         89.0
# 714   7.0         58.0
# 715  14.0         86.0
# 716   6.0         53.0
# 717  17.0        105.0
#
# [718 rows x 2 columns]

# %%
df.Total_Score.value_counts()
# Out:
# Total_Score
# 103.0    19
# 81.0     19
# 86.0     18
# 82.0     16
# 84.0     15
#          ..
# 33.0      1
# 24.0      1
# 25.0      1
# 29.0      1
# 5.0       1
# Name: count, Length: 105, dtype: int64

# %%
sub = df[df.isin([20]).any(axis=1)]

# %%
sub
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  DV_Rating  \
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0  Very Good
# 6     7.0   ALPHA  15.0  10.0  20.0  20.0  15.0  14.0  101.0   0       Good
# 7     8.0   ALPHA  17.0  17.0  19.0  20.0  19.0  13.0  113.0   0       Good
# 8     9.0   ALPHA  10.0  18.0   0.0  20.0  19.0  15.0   91.0   1       Poor
# 9    10.0   ALPHA  18.0  19.0  20.0  20.0  20.0  15.0  122.0   0  Very Good
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..        ...
# 705   0.0    ZETA  16.0   0.0  11.0  16.0  20.0   0.0   63.0   2       Good
# 709   0.0    ZETA  19.0  17.0  12.0  17.0  20.0  16.0  101.0   0  Very Good
# 711   0.0    ZETA  18.0   9.0  12.0  20.0  16.0  16.0   91.0   1  Very Good
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3       Poor
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0  Very Good
#
#     M-II_Rating  PP_Rating BEEE_Rating  FL_Rating FIMS_Rating  Total_Score  \
# 4          Good  Very Good   Very Good  Very Good   Very Good        111.0
# 6          Poor  Very Good   Very Good       Good        Good         94.0
# 7          Good  Very Good   Very Good  Very Good        Good        105.0
# 8     Very Good       Poor   Very Good  Very Good        Good         82.0
# 9     Very Good  Very Good   Very Good  Very Good        Good        112.0
# ..          ...        ...         ...        ...         ...          ...
# 705        Poor       Poor        Good  Very Good        Poor         63.0
# 709        Good       Poor        Good  Very Good        Good        101.0
# 711        Poor       Poor   Very Good       Good        Good         91.0
# 714        Poor       Poor        Poor  Very Good        Poor         58.0
# 717        Good       Good        Good  Very Good   Very Good        105.0
#
#     Overall_Rating
# 4             Poor
# 6             Poor
# 7             Poor
# 8             Poor
# 9             Poor
# ..             ...
# 705           Poor
# 709           Poor
# 711           Poor
# 714           Poor
# 717           Poor
#
# [300 rows x 18 columns]

# %%
#new Datasets.value()

# %%
sub=df.tail(30)
sub
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  DV_Rating  \
# 688   0.0    ZETA  16.0   1.0   8.0  20.0  13.0  13.0   71.0   2       Good
# 689   0.0    ZETA   6.0   3.0   4.0   9.0  10.0  15.0   47.0   4       Poor
# 690   0.0    ZETA  18.0   6.0   7.0  15.0  19.0  18.0   83.0   2  Very Good
# 691   0.0    ZETA  15.0   3.0   9.0  16.0  16.0  18.0   77.0   2       Good
# 692   0.0    ZETA  20.0  15.0  17.0  18.0  20.0  17.0  107.0   0  Very Good
# 693   0.0    ZETA  20.0   1.0   8.0  20.0  18.0  18.0   85.0   2  Very Good
# 694   0.0    ZETA  20.0  19.0  14.0  20.0  20.0  19.0  112.0   0  Very Good
# 695   0.0    ZETA  15.0   8.0  15.0  17.0  20.0  19.0   94.0   1       Good
# 696   0.0    ZETA  16.0   7.0  14.0  17.0  19.0  18.0   91.0   1       Good
# 697   0.0    ZETA  18.0  15.0  15.0  20.0  20.0  19.0  107.0   0  Very Good
# 698   0.0    ZETA  18.0  17.0  15.0  16.0  20.0  16.0  102.0   0  Very Good
# 699   0.0    ZETA  16.0  11.0   8.0  18.0  19.0  16.0   88.0   1       Good
# 700   0.0    ZETA  17.0   7.0   7.0  12.0  13.0   9.0   65.0   3       Good
# 701   0.0    ZETA  15.0   4.0   3.0  13.0  14.0  13.0   62.0   2       Good
# 702   0.0    ZETA  15.0   8.0   6.0  18.0  17.0  15.0   79.0   2       Good
# 703   0.0    ZETA  16.0   6.0  15.0  17.0  20.0  16.0   90.0   1       Good
# 704   0.0    ZETA  18.0   7.0  14.0  19.0  16.0  18.0   92.0   1  Very Good
# 705   0.0    ZETA  16.0   0.0  11.0  16.0  20.0   0.0   63.0   2       Good
# 706   0.0    ZETA  16.0   8.0   8.0  18.0  19.0  17.0   86.0   2       Good
# 707   0.0    ZETA  16.0   8.0  11.0  19.0  15.0  17.0   86.0   1       Good
# 708   0.0    ZETA  18.0   1.0  10.0  19.0  16.0  16.0   80.0   1  Very Good
# 709   0.0    ZETA  19.0  17.0  12.0  17.0  20.0  16.0  101.0   0  Very Good
# 710   0.0    ZETA  18.0   1.0   6.0  12.0  11.0   9.0   57.0   3  Very Good
# 711   0.0    ZETA  18.0   9.0  12.0  20.0  16.0  16.0   91.0   1  Very Good
# 712   0.0    ZETA  15.0  10.0   7.0  18.0  18.0  16.0   84.0   1       Good
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2  Very Good
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3       Poor
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1       Good
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3       Poor
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0  Very Good
#
#     M-II_Rating PP_Rating BEEE_Rating  FL_Rating FIMS_Rating  Total_Score  \
# 688        Poor      Poor   Very Good       Good        Good         71.0
# 689        Poor      Poor        Poor       Poor        Good         47.0
# 690        Poor      Poor        Good  Very Good   Very Good         83.0
# 691        Poor      Poor        Good       Good   Very Good         77.0
# 692        Good      Good   Very Good  Very Good        Good        107.0
# 693        Poor      Poor   Very Good  Very Good   Very Good         85.0
# 694   Very Good      Good   Very Good  Very Good   Very Good        112.0
# 695        Poor      Good        Good  Very Good   Very Good         94.0
# 696        Poor      Good        Good  Very Good   Very Good         91.0
# 697        Good      Good   Very Good  Very Good   Very Good        107.0
# 698        Good      Good        Good  Very Good        Good        102.0
# 699        Poor      Poor   Very Good  Very Good        Good         88.0
# 700        Poor      Poor        Poor       Good        Poor         65.0
# 701        Poor      Poor        Good       Good        Good         62.0
# 702        Poor      Poor   Very Good       Good        Good         79.0
# 703        Poor      Good        Good  Very Good        Good         90.0
# 704        Poor      Good   Very Good       Good   Very Good         92.0
# 705        Poor      Poor        Good  Very Good        Poor         63.0
# 706        Poor      Poor   Very Good  Very Good        Good         86.0
# 707        Poor      Poor   Very Good       Good        Good         86.0
# 708        Poor      Poor   Very Good       Good        Good         80.0
# 709        Good      Poor        Good  Very Good        Good        101.0
# 710        Poor      Poor        Poor       Poor        Poor         57.0
# 711        Poor      Poor   Very Good       Good        Good         91.0
# 712        Poor      Poor   Very Good  Very Good        Good         84.0
# 713        Poor      Poor   Very Good       Good   Very Good         89.0
# 714        Poor      Poor        Poor  Very Good        Poor         58.0
# 715        Poor      Good        Good       Good   Very Good         86.0
# 716        Poor      Poor        Poor       Good        Poor         53.0
# 717        Good      Good        Good  Very Good   Very Good        105.0
#
#     Overall_Rating
# 688           Poor
# 689           Poor
# 690           Poor
# 691           Poor
# 692           Poor
# 693           Poor
# 694           Poor
# 695           Poor
# 696           Poor
# 697           Poor
# 698           Poor
# 699           Poor
# 700           Poor
# 701           Poor
# 702           Poor
# 703           Poor
# 704           Poor
# 705           Poor
# 706           Poor
# 707           Poor
# 708           Poor
# 709           Poor
# 710           Poor
# 711           Poor
# 712           Poor
# 713           Poor
# 714           Poor
# 715           Poor
# 716           Poor
# 717           Poor

# %%
df.describe()
# Out:
#              S.NO          DV        M-II          PP        BEEE          FL  \
# count  718.000000  718.000000  718.000000  718.000000  718.000000  718.000000
# mean   251.951253   14.746518    9.922006   12.733983   13.250696   15.501393
# std    193.921102    4.629339    6.610886    5.848171    5.817407    4.544449
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     63.250000   12.000000    4.000000    9.000000    9.000000   13.000000
# 50%    242.500000   16.000000   10.000000   14.000000   15.000000   16.000000
# 75%    421.750000   18.000000   16.000000   18.000000   18.000000   20.000000
# max    601.000000   20.000000   20.000000   20.000000   20.000000   20.000000
#
#              FIMS       Total          BC  Total_Score
# count  718.000000  718.000000  718.000000   718.000000
# mean    14.008357  332.114206    1.406685    80.162953
# std      4.761238  196.082514    1.553889    25.652759
# min      0.000000    0.000000    0.000000     0.000000
# 25%     12.000000  148.250000    0.000000    64.000000
# 50%     15.000000  320.500000    1.000000    84.000000
# 75%     18.000000  502.750000    2.000000   101.000000
# max     20.000000  717.000000    6.000000   120.000000

# %%
sub
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  DV_Rating  \
# 688   0.0    ZETA  16.0   1.0   8.0  20.0  13.0  13.0   71.0   2       Good
# 689   0.0    ZETA   6.0   3.0   4.0   9.0  10.0  15.0   47.0   4       Poor
# 690   0.0    ZETA  18.0   6.0   7.0  15.0  19.0  18.0   83.0   2  Very Good
# 691   0.0    ZETA  15.0   3.0   9.0  16.0  16.0  18.0   77.0   2       Good
# 692   0.0    ZETA  20.0  15.0  17.0  18.0  20.0  17.0  107.0   0  Very Good
# 693   0.0    ZETA  20.0   1.0   8.0  20.0  18.0  18.0   85.0   2  Very Good
# 694   0.0    ZETA  20.0  19.0  14.0  20.0  20.0  19.0  112.0   0  Very Good
# 695   0.0    ZETA  15.0   8.0  15.0  17.0  20.0  19.0   94.0   1       Good
# 696   0.0    ZETA  16.0   7.0  14.0  17.0  19.0  18.0   91.0   1       Good
# 697   0.0    ZETA  18.0  15.0  15.0  20.0  20.0  19.0  107.0   0  Very Good
# 698   0.0    ZETA  18.0  17.0  15.0  16.0  20.0  16.0  102.0   0  Very Good
# 699   0.0    ZETA  16.0  11.0   8.0  18.0  19.0  16.0   88.0   1       Good
# 700   0.0    ZETA  17.0   7.0   7.0  12.0  13.0   9.0   65.0   3       Good
# 701   0.0    ZETA  15.0   4.0   3.0  13.0  14.0  13.0   62.0   2       Good
# 702   0.0    ZETA  15.0   8.0   6.0  18.0  17.0  15.0   79.0   2       Good
# 703   0.0    ZETA  16.0   6.0  15.0  17.0  20.0  16.0   90.0   1       Good
# 704   0.0    ZETA  18.0   7.0  14.0  19.0  16.0  18.0   92.0   1  Very Good
# 705   0.0    ZETA  16.0   0.0  11.0  16.0  20.0   0.0   63.0   2       Good
# 706   0.0    ZETA  16.0   8.0   8.0  18.0  19.0  17.0   86.0   2       Good
# 707   0.0    ZETA  16.0   8.0  11.0  19.0  15.0  17.0   86.0   1       Good
# 708   0.0    ZETA  18.0   1.0  10.0  19.0  16.0  16.0   80.0   1  Very Good
# 709   0.0    ZETA  19.0  17.0  12.0  17.0  20.0  16.0  101.0   0  Very Good
# 710   0.0    ZETA  18.0   1.0   6.0  12.0  11.0   9.0   57.0   3  Very Good
# 711   0.0    ZETA  18.0   9.0  12.0  20.0  16.0  16.0   91.0   1  Very Good
# 712   0.0    ZETA  15.0  10.0   7.0  18.0  18.0  16.0   84.0   1       Good
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2  Very Good
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3       Poor
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1       Good
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3       Poor
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0  Very Good
#
#     M-II_Rating PP_Rating BEEE_Rating  FL_Rating FIMS_Rating  Total_Score  \
# 688        Poor      Poor   Very Good       Good        Good         71.0
# 689        Poor      Poor        Poor       Poor        Good         47.0
# 690        Poor      Poor        Good  Very Good   Very Good         83.0
# 691        Poor      Poor        Good       Good   Very Good         77.0
# 692        Good      Good   Very Good  Very Good        Good        107.0
# 693        Poor      Poor   Very Good  Very Good   Very Good         85.0
# 694   Very Good      Good   Very Good  Very Good   Very Good        112.0
# 695        Poor      Good        Good  Very Good   Very Good         94.0
# 696        Poor      Good        Good  Very Good   Very Good         91.0
# 697        Good      Good   Very Good  Very Good   Very Good        107.0
# 698        Good      Good        Good  Very Good        Good        102.0
# 699        Poor      Poor   Very Good  Very Good        Good         88.0
# 700        Poor      Poor        Poor       Good        Poor         65.0
# 701        Poor      Poor        Good       Good        Good         62.0
# 702        Poor      Poor   Very Good       Good        Good         79.0
# 703        Poor      Good        Good  Very Good        Good         90.0
# 704        Poor      Good   Very Good       Good   Very Good         92.0
# 705        Poor      Poor        Good  Very Good        Poor         63.0
# 706        Poor      Poor   Very Good  Very Good        Good         86.0
# 707        Poor      Poor   Very Good       Good        Good         86.0
# 708        Poor      Poor   Very Good       Good        Good         80.0
# 709        Good      Poor        Good  Very Good        Good        101.0
# 710        Poor      Poor        Poor       Poor        Poor         57.0
# 711        Poor      Poor   Very Good       Good        Good         91.0
# 712        Poor      Poor   Very Good  Very Good        Good         84.0
# 713        Poor      Poor   Very Good       Good   Very Good         89.0
# 714        Poor      Poor        Poor  Very Good        Poor         58.0
# 715        Poor      Good        Good       Good   Very Good         86.0
# 716        Poor      Poor        Poor       Good        Poor         53.0
# 717        Good      Good        Good  Very Good   Very Good        105.0
#
#     Overall_Rating
# 688           Poor
# 689           Poor
# 690           Poor
# 691           Poor
# 692           Poor
# 693           Poor
# 694           Poor
# 695           Poor
# 696           Poor
# 697           Poor
# 698           Poor
# 699           Poor
# 700           Poor
# 701           Poor
# 702           Poor
# 703           Poor
# 704           Poor
# 705           Poor
# 706           Poor
# 707           Poor
# 708           Poor
# 709           Poor
# 710           Poor
# 711           Poor
# 712           Poor
# 713           Poor
# 714           Poor
# 715           Poor
# 716           Poor
# 717           Poor

# %%
DV_Rating_counts=sub.DV_Rating.value_counts()

# %%
DV_Rating_counts
# Out:
# DV_Rating
# Good         14
# Very Good    13
# Poor          3
# Name: count, dtype: int64

# %%
DV_Rating_counts.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
# Out:
# <Axes: ylabel='count'>

# %%
PP_Rating_counts=sub.PP_Rating.value_counts()

# %%
PP_Rating_counts
# Out:
# PP_Rating
# Poor    20
# Good    10
# Name: count, dtype: int64

# %%
PP_Rating_counts.plot(kind='pie', autopct='%1.1f%%', colors=['silver', 'gold', 'magenta', 'lime', 'violet', 'darkorange']).plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
# Out:
# []

# %%
df["DV"] = pd.to_numeric(df["DV"], errors="coerce")

# Define passing mark
passing_mark = 10

# Count students who passed the DV subject
passed_dv_count = df[df["DV"] >= passing_mark].shape[0]

print(f"Number of students who passed DV in Alpha section: {passed_dv_count}")
# Out:
# Number of students who passed DV in Alpha section: 629

# %%
D=(sub['DV']<10)&(sub['SECTION']=='DELTA')
D.value_counts()
# Out:
# False    30
# Name: count, dtype: int64

# %%
import pandas as p
file_path = "MIDMARKS.xlsx" 
xls = pd.ExcelFile(file_path)
df = xls.parse("SEM2 MID 1 - ALPHA")
df.iloc[:, 2:] = df.iloc[:, 2:].apply(pd.to_numeric, errors="coerce")
section_avg = df.groupby("SECTION").mean(numeric_only=True)
print("Average marks for each section:")
print(section_avg)
# Out:
# Average marks for each section:
#           S.NO
# SECTION
# ALPHA     45.5
# BETA     135.5
# DELTA    225.5
# EPSILON  314.5
# GAMMA    403.5
# OMEGA    493.5
# SIGMA    570.0
# ZETA       NaN

# %%
import pandas as pd
file_path = "Copy-of-MIDMARKS_1_.csv" 
k = pd.read_excel("MIDMARKS.xlsx")
for col in k.columns[2:]:
    k[col] = pd.to_numeric(k[col], errors='coerce')
passing_marks = 10
subject_section_pass = k.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] >= passing_marks).sum()
)
subject_section_fail = k.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] < passing_marks).sum()
)
total_students_per_section = k.groupby('SECTION').size()
prob_pass = subject_section_pass.div(total_students_per_section, axis=0)
prob_fail = subject_section_fail.div(total_students_per_section, axis=0)
print("Number of students passing each subject in each section:")
print(subject_section_pass)
print("\nNumber of students failing each subject in each section:")
print(subject_section_fail)
print("\nProbability of students passing each subject in each section:")
print(prob_pass)
print("\nProbability of students failing each subject in each section:")
print(prob_fail)
# Out:
# Number of students passing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    73    72  78    82  89    68
# BETA     73    65  82    49  89    79
# DELTA    76    45  62    44  89    86
# EPSILON  84    24  39    71  80    66
# GAMMA    79    44  54    73  88    67
# OMEGA    80    32  74    69  78    83
# SIGMA    57    43  51    46  60    55
# ZETA     82    27  40    72  75    70
#
# Number of students failing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    17    18  11     7   0    21
# BETA     17    25   7    40   0    11
# DELTA    12    43  27    44   0     2
# EPSILON   3    63  48    16   7    21
# GAMMA     8    43  33    14   0    19
# OMEGA     8    56  13    15   7     0
# SIGMA     3    17   8    14   0     3
# ZETA      7    61  48    16  14    17
#
# Probability of students passing each subject in each section:
#                DV      M-II        PP      BEEE        FL      FIMS
# SECTION
# ALPHA    0.811111  0.800000  0.866667  0.911111  0.988889  0.755556
# BETA     0.811111  0.722222  0.911111  0.544444  0.988889  0.877778
# DELTA    0.844444  0.500000  0.688889  0.488889  0.988889  0.955556
# EPSILON  0.954545  0.272727  0.443182  0.806818  0.909091  0.750000
# GAMMA    0.877778  0.488889  0.600000  0.811111  0.977778  0.744444
# OMEGA    0.888889  0.355556  0.822222  0.766667  0.866667  0.922222
# SIGMA    0.904762  0.682540  0.809524  0.730159  0.952381  0.873016
# ZETA     0.911111  0.300000  0.444444  0.800000  0.833333  0.777778
#
# Probability of students failing each subject in each section:
#                DV      M-II        PP      BEEE        FL      FIMS
# SECTION
# ALPHA    0.188889  0.200000  0.122222  0.077778  0.000000  0.233333
# BETA     0.188889  0.277778  0.077778  0.444444  0.000000  0.122222
# DELTA    0.133333  0.477778  0.300000  0.488889  0.000000  0.022222
# EPSILON  0.034091  0.715909  0.545455  0.181818  0.079545  0.238636
# GAMMA    0.088889  0.477778  0.366667  0.155556  0.000000  0.211111
# OMEGA    0.088889  0.622222  0.144444  0.166667  0.077778  0.000000
# SIGMA    0.047619  0.269841  0.126984  0.222222  0.000000  0.047619
# ZETA     0.077778  0.677778  0.533333  0.177778  0.155556  0.188889
# C:\Users\HARSHITHA HRIDYA\AppData\Local\Temp\ipykernel_12108\3759045210.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   subject_section_pass = k.groupby('SECTION').apply(
# C:\Users\HARSHITHA HRIDYA\AppData\Local\Temp\ipykernel_12108\3759045210.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   subject_section_fail = k.groupby('SECTION').apply(

# %%
df[df['DV'] < 10].value_counts()
# Out:
# S.NO   SECTION  DV   M-II  PP    BEEE  FL    FIMS
# 21.0   ALPHA    4.0  2.0   5.0   3.0   16.0  9.0     1
# 26.0   ALPHA    6.0  10.0  10.0  11.0  13.0  10.0    1
# 28.0   ALPHA    5.0  4.0   3.0   12.0  13.0  5.0     1
# 30.0   ALPHA    8.0  2.0   11.0  10.0  13.0  12.0    1
# 36.0   ALPHA    8.0  13.0  13.0  12.0  14.0  7.0     1
# 51.0   ALPHA    1.0  16.0  15.0  13.0  10.0  11.0    1
# 52.0   ALPHA    6.0  12.0  10.0  11.0  10.0  3.0     1
# 54.0   ALPHA    8.0  13.0  9.0   11.0  10.0  10.0    1
# 58.0   ALPHA    2.0  2.0   4.0   10.0  10.0  3.0     1
# 62.0   ALPHA    8.0  8.0   15.0  9.0   10.0  9.0     1
# 66.0   ALPHA    9.0  13.0  8.0   15.0  10.0  11.0    1
# 71.0   ALPHA    4.0  2.0   16.0  10.0  15.0  9.0     1
# 73.0   ALPHA    7.0  0.0   15.0  10.0  18.0  11.0    1
# 76.0   ALPHA    5.0  8.0   7.0   15.0  10.0  2.0     1
# 86.0   ALPHA    3.0  4.0   14.0  13.0  18.0  13.0    1
# 89.0   ALPHA    2.0  17.0  0.0   3.0   15.0  2.0     1
# 97.0   BETA     8.0  17.0  3.0   12.0  18.0  9.0     1
# 98.0   BETA     8.0  16.0  14.0  17.0  13.0  13.0    1
# 99.0   BETA     6.0  7.0   16.0  9.0   13.0  13.0    1
# 100.0  BETA     9.0  11.0  9.0   10.0  13.0  12.0    1
# 107.0  BETA     9.0  13.0  17.0  6.0   18.0  15.0    1
# 111.0  BETA     8.0  11.0  14.0  3.0   18.0  10.0    1
# 119.0  BETA     9.0  9.0   15.0  4.0   15.0  17.0    1
# 122.0  BETA     8.0  11.0  14.0  6.0   15.0  9.0     1
# 126.0  BETA     5.0  16.0  9.0   7.0   18.0  14.0    1
# 128.0  BETA     7.0  4.0   12.0  4.0   13.0  11.0    1
# 136.0  BETA     9.0  8.0   14.0  11.0  13.0  14.0    1
# 140.0  BETA     5.0  0.0   12.0  4.0   20.0  15.0    1
# 148.0  BETA     9.0  5.0   6.0   8.0   13.0  4.0     1
# 161.0  BETA     7.0  0.0   14.0  5.0   10.0  5.0     1
# 170.0  BETA     9.0  0.0   9.0   3.0   10.0  11.0    1
# 173.0  BETA     7.0  13.0  19.0  12.0  10.0  9.0     1
# 177.0  BETA     6.0  0.0   13.0  8.0   18.0  14.0    1
# 188.0  DELTA    8.0  0.0   5.0   3.0   10.0  20.0    1
# 191.0  DELTA    5.0  0.0   1.0   1.0   10.0  5.0     1
# 195.0  DELTA    6.0  0.0   1.0   0.0   10.0  13.0    1
# 201.0  DELTA    9.0  10.0  9.0   3.0   15.0  16.0    1
# 206.0  DELTA    9.0  8.0   1.0   1.0   15.0  16.0    1
# 210.0  DELTA    9.0  6.0   15.0  12.0  15.0  15.0    1
# 215.0  DELTA    9.0  3.0   4.0   2.0   10.0  15.0    1
# 223.0  DELTA    7.0  10.0  7.0   2.0   10.0  15.0    1
# 224.0  DELTA    4.0  15.0  4.0   5.0   10.0  14.0    1
# 241.0  DELTA    6.0  6.0   2.0   3.0   10.0  11.0    1
# 270.0  DELTA    9.0  5.0   5.0   1.0   10.0  11.0    1
# 338.0  EPSILON  5.0  0.0   3.0   11.0  7.0   10.0    1
# 346.0  EPSILON  6.0  0.0   1.0   11.0  9.0   4.0     1
# 358.0  EPSILON  9.0  0.0   2.0   3.0   11.0  1.0     1
# 359.0  GAMMA    6.0  0.0   3.0   3.0   10.0  4.0     1
# 360.0  GAMMA    9.0  3.0   3.0   12.0  10.0  5.0     1
# 361.0  GAMMA    5.0  3.0   9.0   10.0  10.0  7.0     1
# 399.0  GAMMA    5.0  3.0   3.0   2.0   10.0  9.0     1
# 407.0  GAMMA    7.0  2.0   2.0   6.0   10.0  7.0     1
# 413.0  GAMMA    8.0  0.0   2.0   6.0   15.0  8.0     1
# 428.0  GAMMA    2.0  5.0   1.0   2.0   10.0  6.0     1
# 465.0  OMEGA    6.0  1.0   9.0   11.0  8.0   10.0    1
# 485.0  OMEGA    6.0  3.0   7.0   11.0  11.0  14.0    1
# 525.0  OMEGA    9.0  1.0   6.0   6.0   10.0  13.0    1
# 550.0  SIGMA    4.0  3.0   2.0   6.0   10.0  8.0     1
# 564.0  SIGMA    5.0  0.0   5.0   4.0   10.0  10.0    1
# Name: count, dtype: int64

# %%
df[df["SECTION"] == "ALPHA"].mean(numeric_only=True)
# Out:
# S.NO    45.5
# dtype: float64

# %%
df[df["SECTION"] == "ALPHA"].std(numeric_only=True)
# Out:
# S.NO    26.124701
# dtype: float64

# %%
from scipy.stats import ttest_ind

# %%
df[df['SECTION']== 'BETA']['DV']
# Out:
# 90     17.0
# 91     14.0
# 92     11.0
# 93     14.0
# 94     12.0
#        ...
# 175    14.0
# 176     6.0
# 177    12.0
# 178    16.0
# 179    15.0
# Name: DV, Length: 90, dtype: object

# %%
print(df.dtypes)
# Out:
# S.NO       float64
# SECTION     object
# DV          object
# M-II        object
# PP          object
# BEEE        object
# FL          object
# FIMS        object
# dtype: object

# %%
from scipy.stats import ttest_ind
ttest_ind(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='BETA']['DV'])
# Out:
# TtestResult(statistic=np.float64(0.6207084248259586), pvalue=np.float64(0.5355854399866022), df=np.float64(178.0))

# %%
ttest_ind(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='BETA']['DV'])
# Out:
# TtestResult(statistic=np.float64(0.6207084248259586), pvalue=np.float64(0.5355854399866022), df=np.float64(178.0))

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='BETA']['DV'])
# Out:
# Chi2ContingencyResult(statistic=0.0, pvalue=1.0, dof=0, expected_freq=array([12., 19., 18., 15., 18., 17., 15., 17., 10., 18., 17., 20., 16.,
#        17., 19., 13., 15., 11., 14., 19.,  4., 14., 17., 20., 15.,  6.,
#        17.,  5., 19.,  8., 11., 12., 17., 14., 17.,  8., 11., 15., 19.,
#        20., 18., 16., 16., 11., 18., 11., 14., 16., 16., 15.,  1.,  6.,
#        17.,  8., 14., 15., 10.,  2., 10., 19., 19.,  8., 12., 11., 12.,
#         9., 12., 12., 16., 20.,  4., 17.,  7., 10., 17.,  5., 17., 13.,
#        19., 19., 19., 18.,  2., 10., 12.,  3., 17., 13.,  2., 10.]))

# %%
df[df['SECTION']=='ALPHA'].DV.mean()
# Out:
# np.float64(13.411111111111111)

# %%
from scipy.stats import ttest_ind

ttest_ind(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='BETA']['DV'])
# Out:
# TtestResult(statistic=np.float64(0.6207084248259586), pvalue=np.float64(0.5355854399866022), df=np.float64(178.0))

# %%
chi2_contingency(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='BETA']['DV'])
# Out:
# Chi2ContingencyResult(statistic=0.0, pvalue=1.0, dof=0, expected_freq=array([12., 19., 18., 15., 18., 17., 15., 17., 10., 18., 17., 20., 16.,
#        17., 19., 13., 15., 11., 14., 19.,  4., 14., 17., 20., 15.,  6.,
#        17.,  5., 19.,  8., 11., 12., 17., 14., 17.,  8., 11., 15., 19.,
#        20., 18., 16., 16., 11., 18., 11., 14., 16., 16., 15.,  1.,  6.,
#        17.,  8., 14., 15., 10.,  2., 10., 19., 19.,  8., 12., 11., 12.,
#         9., 12., 12., 16., 20.,  4., 17.,  7., 10., 17.,  5., 17., 13.,
#        19., 19., 19., 18.,  2., 10., 12.,  3., 17., 13.,  2., 10.]))

# %%
import scipy.stats as stats

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='ALPHA']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# -3.0546455966439896 0.002972712305590382

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='BETA']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# -5.017987098279169 2.6536889941946247e-06

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='DELTA']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='EPSILON']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='GAMMA']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='OMEGA']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='SIGMA']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.linspace(0, 10, 100)  
y = np.sin(x)


plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sine Wave")
plt.show()



plt.scatter(x, y, color='red', marker='o', label='Data Points') 
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot of Sine Wave")
plt.legend()  
plt.show()


plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)  
plt.plot(x, y, color='blue')
plt.title("Sine Wave")

plt.subplot(1, 2, 2)  
plt.plot(x, np.cos(x), color='green')
plt.title("Cosine Wave")

plt.tight_layout() 
plt.show()


categories = ['A', 'B', 'C', 'D']
values = [25, 15, 30, 10]

plt.bar(categories, values, color='skyblue')
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Bar Chart")
plt.show()


data = np.random.randn(1000) 

plt.hist(data, bins=30, color='lightgreen', edgecolor='black') # Bins specify how many bars to create
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()
